# %% [markdown]
# # Team Project

# %%
import pandas as pd

# %%
df_employees = pd.read_csv('../user_access_logs/employees.csv')
df_employees.head()
# Out:
#   employee_number first_name last_name                             email  \
# 0       EMP003037    Juliana  Burbudge  juliana.burbudge@consultants.com
# 1       EMP003045     Lizzie      Blue       lizzie.blue@consultants.com
# 2       EMP003051    Marjory  Selcraig  marjory.selcraig@consultants.com
# 3       EMP003068     Aguste  O'Connor   aguste.o'connor@consultants.com
# 4       EMP003097    Clemens    Kopman    clemens.kopman@consultants.com
#
#                title
# 0  Director of Sales
# 1    Sales Assistant
# 2    Sales Assistant
# 3    Sales Assistant
# 4    Account Manager

# %%
df_system_access = pd.read_csv('../user_access_logs/system_access.csv')
df_system_access.head()
# Out:
#       id    access_level
# 0  17263   Account Admin
# 1  10275  Contract Entry
# 2   7568  Contract Entry
# 3  21986   Account Admin
# 4  20614   Account Admin

# %%
df_system_access['id'] = 'EMP' + df_system_access['id'].astype(str).str.zfill(6)
df_system_access
# Out:
#             id        access_level
# 0    EMP017263       Account Admin
# 1    EMP010275      Contract Entry
# 2    EMP007568      Contract Entry
# 3    EMP021986       Account Admin
# 4    EMP020614       Account Admin
# ..         ...                 ...
# 849  EMP007600      Contract Entry
# 850  EMP011112  Approval - Manager
# 851  EMP005295      Contract Entry
# 852  EMP007470       Account Admin
# 853  EMP016383      Contract Entry
#
# [854 rows x 2 columns]

# %%
df_system_access.rename(columns={'id': 'employee_number'},inplace=True)
df_system_access.set_index('employee_number', inplace=True)
df_employees.set_index('employee_number', inplace=True)

# %%
df = df_employees.join(df_system_access, how='left')
df.head(25)
# Out:
#                 first_name last_name                             email  \
# employee_number
# EMP003037          Juliana  Burbudge  juliana.burbudge@consultants.com
# EMP003045           Lizzie      Blue       lizzie.blue@consultants.com
# EMP003051          Marjory  Selcraig  marjory.selcraig@consultants.com
# EMP003068           Aguste  O'Connor   aguste.o'connor@consultants.com
# EMP003097          Clemens    Kopman    clemens.kopman@consultants.com
# EMP003133         Donielle   Midgley  donielle.midgley@consultants.com
# EMP003134          Marcela    Thieme    marcela.thieme@consultants.com
# EMP003180            Haily   Wadeson     haily.wadeson@consultants.com
# EMP003265           Natala      Judd       natala.judd@consultants.com
# EMP003287            Gayla     Aldin       gayla.aldin@consultants.com
# EMP003291          Gweneth    Abbate    gweneth.abbate@consultants.com
# EMP003299            Nerte   Luipold     nerte.luipold@consultants.com
# ...

# %%
df.loc[df['access_level'].notnull()]
# Out:
#                  first_name   last_name                                 email  \
# employee_number
# EMP003045            Lizzie        Blue           lizzie.blue@consultants.com
# EMP003051           Marjory    Selcraig      marjory.selcraig@consultants.com
# EMP003068            Aguste    O'Connor       aguste.o'connor@consultants.com
# EMP003097           Clemens      Kopman        clemens.kopman@consultants.com
# EMP003133          Donielle     Midgley      donielle.midgley@consultants.com
# ...                     ...         ...                                   ...
# EMP024864          Kristina       Yakov        kristina.yakov@consultants.com
# EMP024885         Margarita  Habbergham  margarita.habbergham@consultants.com
# EMP024890          Prescott   Southward    prescott.southward@consultants.com
# EMP024896             Raine     Learned         raine.learned@consultants.com
# EMP024931        Frederique        Fant       frederique.fant@consultants.com
#
# ...

# %%
print(len(df))
# Out:
# 1280

# %%
subset_df = df.loc[df['access_level'].isnull()].copy()
print(len(subset_df))
subset_df.tail()
# Out:
# 142
#                   first_name last_name                              email  \
# employee_number
# EMP023849                Sib   Raymond        sib.raymond@consultants.com
# EMP023911        Constantine     Seath  constantine.seath@consultants.com
# EMP023999              Merla     Siman        merla.siman@consultants.com
# EMP024117              Netti  Lebreton     netti.lebreton@consultants.com
# EMP024191              Danny    Vinten       danny.vinten@consultants.com
#
#                              title access_level
# employee_number
# EMP023849        Director of Sales          NaN
# EMP023911        Director of Sales          NaN
# EMP023999          Account Manager          NaN
# EMP024117          Account Manager          NaN
# EMP024191          Account Manager          NaN

# %%
subset_df.loc[subset_df['title'] == 'Account Manager', 'access_level'] = 'approval - manager'
subset_df.tail()
# Out:
#                   first_name last_name                              email  \
# employee_number
# EMP023849                Sib   Raymond        sib.raymond@consultants.com
# EMP023911        Constantine     Seath  constantine.seath@consultants.com
# EMP023999              Merla     Siman        merla.siman@consultants.com
# EMP024117              Netti  Lebreton     netti.lebreton@consultants.com
# EMP024191              Danny    Vinten       danny.vinten@consultants.com
#
#                              title        access_level
# employee_number
# EMP023849        Director of Sales                 NaN
# EMP023911        Director of Sales                 NaN
# EMP023999          Account Manager  approval - manager
# EMP024117          Account Manager  approval - manager
# EMP024191          Account Manager  approval - manager

# %%
df_missing =df.loc[df['access_level'].isnull()]
df_missing
# Out:
#                   first_name last_name                              email  \
# employee_number
# EMP003037            Juliana  Burbudge   juliana.burbudge@consultants.com
# EMP003265             Natala      Judd        natala.judd@consultants.com
# EMP003291            Gweneth    Abbate     gweneth.abbate@consultants.com
# EMP003605               Jany    Bianco        jany.bianco@consultants.com
# EMP003684           Annmarie   Scrange   annmarie.scrange@consultants.com
# ...                      ...       ...                                ...
# EMP023849                Sib   Raymond        sib.raymond@consultants.com
# EMP023911        Constantine     Seath  constantine.seath@consultants.com
# EMP023999              Merla     Siman        merla.siman@consultants.com
# EMP024117              Netti  Lebreton     netti.lebreton@consultants.com
# EMP024191              Danny    Vinten       danny.vinten@consultants.com
#
#                              title access_level
# ...

# %%
subset_df.loc[subset_df['title'] == 'sales assistant','access_level'] = 'Contract Entry'
subset_df.tail()
# Out:
#                   first_name last_name                              email  \
# employee_number
# EMP023849                Sib   Raymond        sib.raymond@consultants.com
# EMP023911        Constantine     Seath  constantine.seath@consultants.com
# EMP023999              Merla     Siman        merla.siman@consultants.com
# EMP024117              Netti  Lebreton     netti.lebreton@consultants.com
# EMP024191              Danny    Vinten       danny.vinten@consultants.com
#
#                              title        access_level
# employee_number
# EMP023849        Director of Sales                 NaN
# EMP023911        Director of Sales                 NaN
# EMP023999          Account Manager  approval - manager
# EMP024117          Account Manager  approval - manager
# EMP024191          Account Manager  approval - manager

# %%
subset_df.loc[subset_df['title'] == 'director of sales', 'access_level'] = 'account admin'

# %%
df.loc[df['access_level'].notnull()]
# Out:
#                  first_name   last_name                                 email  \
# employee_number
# EMP003045            Lizzie        Blue           lizzie.blue@consultants.com
# EMP003051           Marjory    Selcraig      marjory.selcraig@consultants.com
# EMP003068            Aguste    O'Connor       aguste.o'connor@consultants.com
# EMP003097           Clemens      Kopman        clemens.kopman@consultants.com
# EMP003133          Donielle     Midgley      donielle.midgley@consultants.com
# ...                     ...         ...                                   ...
# EMP024864          Kristina       Yakov        kristina.yakov@consultants.com
# EMP024885         Margarita  Habbergham  margarita.habbergham@consultants.com
# EMP024890          Prescott   Southward    prescott.southward@consultants.com
# EMP024896             Raine     Learned         raine.learned@consultants.com
# EMP024931        Frederique        Fant       frederique.fant@consultants.com
#
# ...

# %%
subset_df.to_csv('FinalResults.csv')
