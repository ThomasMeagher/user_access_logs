# %% [markdown]
# # Team Project

# %%
import pandas as pd

# %%
df_employees = pd.read_csv('../user_access_logs/employees.csv')
df_system_access = pd.read_csv('../user_access_logs/system_access.csv')
df_employees.set_index('employee_number', inplace=True)
df_employees = df_employees.set_index('last_name')
df = df_employees.join(df_system_access, how='left')
df.head(25)
# Out:
#             first_name                               email              title  \
# Abbate         Gweneth      gweneth.abbate@consultants.com  Director of Sales
# Abbyss          Arthur       arthur.abbyss@consultants.com    Account Manager
# Abdee         Beatrice      beatrice.abdee@consultants.com    Sales Assistant
# Abels            Dyane         dyane.abels@consultants.com  Director of Sales
# Aberdalgy      Christy   christy.aberdalgy@consultants.com    Sales Assistant
# Abramowitch      Tades   tades.abramowitch@consultants.com    Account Manager
# Adamiec      Hyacintha   hyacintha.adamiec@consultants.com  Director of Sales
# Addington         Audi      audi.addington@consultants.com    Sales Assistant
# Adenot           Rhett        rhett.adenot@consultants.com    Account Manager
# Adkin         Prentiss      prentiss.adkin@consultants.com    Sales Assistant
# Agius           Dahlia        dahlia.agius@consultants.com    Account Manager
# ...
